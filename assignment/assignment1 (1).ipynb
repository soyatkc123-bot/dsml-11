# %%
text = "Hello World"
print(text.upper())
# Out:
# HELLO WORLD

# %%
print(text.lower())
# Out:
# hello world

# %%
print(text.capitalize())
# Out:
# Hello world

# %%
print(text.replace("World","Python"))
# Out:
# Hello Python

# %%
print(text.find("n"))
# Out:
# -1

# %%
print(text.startswith("H"))
# Out:
# True

# %%
print(text.endswith("h"))
# Out:
# False

# %%
print(text.strip())
# Out:
# Hello World

# %%
print(text.count("l"))
# Out:
# 3

# %%
print("-".join(text))
# Out:
# H-e-l-l-o- -W-o-r-l-d

# %%
text1 = input("enter a name:")
print(text1)
print(text1.upper())
print(text1.lower())
print(text1.replace("Soyat","Swet"))
print("-".join(text1))
print(text1.count("t"))
# Out:
# enter a name:Soyat KC
# Soyat KC
# SOYAT KC
# soyat kc
# Swet KC
# S-o-y-a-t- -K-C
# 1
