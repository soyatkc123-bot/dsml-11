# %%
number=123
print(type(number))
# Out:
# <class 'int'>

# %%
float=1.11
type(float)
# Out:
# float

# %%
complex = 3+3j
type(complex)
# Out:
# complex

# %%
x=122
y=float(x)
print(y)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_22002/2151286417.py in <cell line: 0>()
#       1 x=122
# ----> 2 y=float(x)
#       3 print(y)
#
# TypeError: 'float' object is not callable

# %%
a = 1
b = 2
sum = a+b
diff = b-a
print(sum,diff)
# Out:
# 3 1

# %%
a= 10
b = 3
mod = a % b
print(mod)
# Out:
# 1

# %%
a=1
b=4
compare=a<b
e=a>b
f=(a!=b)
print(compare,e,f)
# Out:
# True False True

# %%
import math
math.floor(44.9)
math.ceil(44.9)
math.gcd(3,6,9,12)
round(22.5)
user=(440)
capacity=128
result=min(user,capacity)
print(result)
# Out:
# 128

# %%
#string
text1=("it's a sunny day.")
text2='he said "hello"'
print(text1)
print(text2)
print(text1+" "+text2)
print(text1,text2)
# Out:
# it's a sunny day.
# he said "hello"
# it's a sunny day. he said "hello"
# it's a sunny day. he said "hello"

# %%
print(text1*2)
# Out:
# it's a sunny day.it's a sunny day.

# %%
data = "Python"
data[0]
# Out:
# 'P'

# %%
data[1:3]#slicing
data[1:5:2]
dat="hello python"
dat[1:11]
# Out:
# 'ello pytho'

# %%
#length
len(dat)
# Out:
# 12

# %%
data1="i am a boy"
print(data1.replace ("boy","girl"))
print(data1.upper())
print(data1.lower())
print(data1.split())
print(data1.strip())
# Out:
# i am a girl
# I AM A BOY
# i am a boy
# ['i', 'am', 'a', 'boy']
# i am a boy
