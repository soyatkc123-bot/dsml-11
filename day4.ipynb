# %%
#list
num = [1,2]
num.append(3)
print(num)
# Out:
# [1, 2, 3]

# %%
#set
numbers = {1,2,2,3}
fruits= {"apple","mango","mango"}
print(numbers)
print(fruits)
# Out:
# {1, 2, 3}
# {'apple', 'mango'}

# %%
nums = {1,2,2,3,3,4}
print(nums)
# Out:
# {1, 2, 3, 4}

# %%
#constructor method
list((1,2,3))
# Out:
# [1, 2, 3]

# %%
list(((1,2,44),(44,55,66)))
# Out:
# [(1, 2, 44), (44, 55, 66)]

# %%
list=[1,2,3]
length = len(list)
print(length)
# Out:
# 3

# %%
my_list=[10,20,30]
my_list[1:4]
my_list[:3]
my_list[::-1]#reverse
# Out:
# [30, 20, 10]

# %%
data2=["apple","mango",1,4]
data2.append(5)
data2#append
# Out:
# ['apple', 'mango', 1, 4, 5]

# %%
data2.extend((6,7,8,9))
data2
# Out:
# ['apple', 'mango', 1, 4, 5, 6, 7, 8, 9]

# %%
data2.insert(2,"soyat")
data2
# Out:
# ['apple', 'mango', 'soyat', 1, 4, 5, 6, 7, 8, 9]

# %%
data2.remove("apple")
data2
# Out:
# ['mango', 'soyat', 1, 4, 5, 6, 7, 8, 9]

# %%
data2.pop(1)
data2
# Out:
# ['mango', 1, 4, 5, 6, 7, 8, 9]

# %%
data2.clear()
data2
# Out:
# []

# %%
data2.extend((1,2,3,4,5))
data2
# Out:
# [1, 2, 3, 4, 5]

# %%
data2.count(5)
# Out:
# 1

# %%
data2.append(2)
data2
# Out:
# [1, 2, 3, 4, 5, 2]

# %%
data2.sort()
data2
# Out:
# [1, 2, 2, 3, 4, 5]

# %%
data2.reverse()
data2
# Out:
# [5, 4, 3, 2, 2, 1]

# %%
data2.copy()
data2
# Out:
# [5, 4, 3, 2, 2, 1]

# %%
data4=[1,2,3,4,5]
data4.append(6)
data4
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
data4.pop()
data4
# Out:
# [1, 2, 3, 4, 5]

# %%
a = input("enter a name")
data=[]
data.append(a)
data
# Out:
# enter a nameishan
# ['ishan']

# %%
from collections import deque
queue = deque(["Ishan","Dippi","Jha"])
queue.append("Singh")
queue.append("BCD")
queue.popleft()
queue.popleft()
queue
# Out:
# deque(['Jha', 'Singh', 'BCD'])

# %%
list = [1,2,3,4]
list1 = list
print(list)
print(list1)
# Out:
# [1, 2, 3, 4]
# [1, 2, 3, 4]

# %%
list3 = list1.copy()
list3
# Out:
# [1, 2, 3, 4]

# %%
list = [[1,2,3,4],[5,6,7,8]]
list.insert(1,55)
list3=list.copy()
print(list)
print(list3)
# Out:
# [[1, 2, 3, 4], 55, [5, 6, 7, 8]]
# [[1, 2, 3, 4], 55, [5, 6, 7, 8]]
