# %%
num = int(input("enter an age:"))
if num >= 18 and num<40:
  print("older")
elif num < 18 :
  print("younger")
else:
  print("adult")
# Out:
# enter an age:41
# adult

# %%
num = int(input("enter an age:"))
if num >= 18 :
  citizen=input("do you have a citizen")
  if (citizen == "yes"):
    print("eligible")
  else:
    print("not eligible")
else:
  print("not eligible")
# Out:
# enter an age:18
# do you have a citizenno
# not eligible

# %%
age =  int(input("age:"))
if age <= 12:
  print("child")
elif age <= 19:
  print("teen")
elif age <= 35:
  print("young adult")
else:
  print("adult")
# Out:
# age:45
# adult

# %%
cgpa = float(input("enter your marks"))
if cgpa == 4:
  print("Aplus")
elif cgpa >= 3.6 and cgpa < 4:
  print("A")
elif cgpa >= 3.2 and cgpa < 3.6:
  print("Bplus")
elif cgpa >= 2.8 and cgpa < 3.2:
    print("b")
elif cgpa >= 2.4 and cgpa < 2.8:
    print("cplus")
elif cgpa >= 2.0 and cgpa < 2.4:
  print("c")
elif cgpa >= 1.6 and cgpa < 2 :
  print("d")
elif cgpa < 1.6:
  print("NG")

else:
  print("undefined")
# Out:
# enter your marks5
# undefined

# %%
num = int(input("enter a num:"))
res = "even" if num % 2 == 0 else "odd"
res
# Out:
# enter a num:1
# 'odd'

# %%
list = [1,2,3,4,6,7,9]
num = int(input("a number:"))
if num % 2 == 0:
  list.append(num)
  print(list)
else:
  list.pop()
  print(list)
# Out:
# a number:2
# [1, 2, 3, 4, 6, 7, 9, 2]

# %%
age = int(input("age:"))
if age >= 18:
  citizenship = input("do you have a card:")
  if age >= 18 and citizenship == "yes":
    print("eligible")
  else:
    print("not eligible")
else:
  print("grow up first")
# Out:
# age:18
# do you have a card:no
# not eligible

# %%
age = int(input("age:"))
if age >= 18:
 license = input("do you have a card:")
 if age >= 18 and license == "yes":
  print("has license")
 else:
  print("no license")
else:
  print("grow up first")
# Out:
# age:76
# do you have a card:no
# no license

# %%
num = int(input("num:"))
if num > 0:
  print("positive")
  if num > 0 and num % 5 == 0:
   print("is divisible by 5")
  else:
   print("not divisible")
else:
  print("negative")
# Out:
# num:5
# positive
# is divisible by 5

# %%
pin = int(input("pin:"))
if pin == 1234:
  balance = int(input("enter a balance:"))
  if pin == 1234 and balance > 1000:
    print("enough balance")
  else:
    print("insufficient")
else:
  print("invalid")
# Out:
# pin:1234
# enter a balance:900
# insufficient

# %%
age = int(input("enter age:"))
if age >= 18:
  license = input("do you have a card:").lower()
  if license == "yes":
    print("Can drive")
  else:
    print("No licence")
else:
  print("Too young")
# Out:
# enter age:18
# do you have a card:YES
# Can drive

# %%
marks = int(input("enter marks:"))
if marks >= 40:
  print("passed")
  if marks >= 80:
    print("Disctiction")
  elif marks >= 60:
    print("First Division")
  else:
    print("Second Division")
else:
  print("Failed")
# Out:
# enter marks:60
# passed
# First Division

# %%
cgpa = float(input("enter gpa: "))

if cgpa > 4:
    print("Undefined")

elif cgpa < 1.6:
    print("NG")

else:
    print("passed")

    if cgpa >= 3.6:
        print("A")

    elif cgpa >= 3:
        print("B+")

    elif cgpa >= 2.6:
        print("C+")

    elif cgpa >= 2:
        print("C")

    else:
        print("D")
# Out:
# enter gpa: 1.7
# passed
# D
